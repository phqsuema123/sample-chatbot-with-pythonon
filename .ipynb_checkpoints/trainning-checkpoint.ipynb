# %%
import random
import json
import pickle
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

# %%
lemmatizer=WordNetLemmatizer()

# %%
with open("intents.json", "r", encoding="utf-8") as f:
    intents = json.load(f)

# %%
word=[]
documents = []
classes = []
ignore_letters=["?","!",",","."]

# %%
for intent in intents["intents"]:
    for pattern in intent["patterns"]:
        word_list = nltk.word_tokenize(pattern)
        word.append(word_list)
        documents.append((word_list, intent["tag"]))
        if intent["tag"] not in classes:
            classes.append(intent["tag"])
print(documents)
# Out:
# [(['hello'], 'greetings'), (['hey'], 'greetings'), (['hi'], 'greetings'), (['good', 'day'], 'greetings'), (['Greetings'], 'greetings'), (['What', "'s", 'up', '?'], 'greetings'), (['how', 'is', 'it', 'going', '?'], 'greetings'), (['cya'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['I', 'am', 'Leaving'], 'goodbye'), (['Have', 'a', 'good', 'day'], 'goodbye'), (['bye'], 'goodbye'), (['cao'], 'goodbye'), (['see', 'ya'], 'goodbye'), (['how', 'old'], 'age'), (['้how', 'old', 'is', 'Phad'], 'age'), (['what', 'is', 'your', 'age'], 'age'), (['how', 'old', 'are', 'you'], 'age'), (['age', '?'], 'age'), (['what', 'is', 'your', 'name'], 'name'), (['what', 'should', 'I', 'call', 'you'], 'name'), (['whats', 'your', 'name', '?'], 'name'), (['who', 'are', 'you', '?'], 'name'), (['What', 'is', 'your', 'religion', '?'], 'religion'), (['what', 'is', 'your', 'attitude', '?'], 'attitude')]

# %%
for intent in intents["intents"]:
    for pattern in intent["patterns"]:
        word_list = nltk.word_tokenize(pattern)
        word.extend(word_list)
        documents.append((word_list, intent["tag"]))
        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# %%
words = [lemmatizer.lemmatize(word) for word in word_list if word not in ignore_letters]
words = sorted(set(words))
print(words)
# Out:
# ['attitude', 'is', 'what', 'your']

# %%
classes=sorted(set(classes))
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
training=[]
output_empty=[0]*len(classes)

for document in documents:
    bag=[]
    word_patterns=document[0]
    word_patterns=[lemmatizer.lemmatize(word.lower())for word in word_patterns]
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
    

    output_row=list(output_empty)
    output_row[classes.index(document[1])] =1
    training.append([bag, output_row])

# %%
random.shuffle(training)
training = [(row[0], row[1]) for row in training] # convert to list of tuples

train_x = [row[0] for row in training] # extract bag of words
train_y = [row[1] for row in training] # extract output row

# %%
model=Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),),activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation="softmax"))

# %%
from tensorflow.keras.optimizers import SGD

sgd = SGD(learning_rate=0.09, momentum=0.9, nesterov=True)
model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=['accuracy'])

hist=model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)

model.save("chatbot_model.h5",hist)
print("Done")
# Out:
# Epoch 1/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.1193 - accuracy: 0.4615
# Epoch 2/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.1728 - accuracy: 0.4423
# Epoch 3/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.1578 - accuracy: 0.4038
# Epoch 4/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6394 - accuracy: 0.4423
# Epoch 5/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5597 - accuracy: 0.4231
# Epoch 6/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.4276 - accuracy: 0.4038
# Epoch 7/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.3714 - accuracy: 0.4231
# Epoch 8/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.3803 - accuracy: 0.4038
# Epoch 9/200
# 11/11 [==============================] - 0s 1ms/step - loss: 2.3639 - accuracy: 0.3462
# Epoch 10/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5493 - accuracy: 0.3846
# Epoch 11/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0096 - accuracy: 0.3654
# Epoch 12/200
# 11/11 [==============================] - 0s 1ms/step - loss: 2.2196 - accuracy: 0.3269
# Epoch 13/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.4678 - accuracy: 0.3462
# Epoch 14/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.4472 - accuracy: 0.3846
# Epoch 15/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.
200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5200 - accuracy: 0.3462
# Epoch 78/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5124 - accuracy: 0.3269
# Epoch 79/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5152 - accuracy: 0.3269
# Epoch 80/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5151 - accuracy: 0.3462
# Epoch 81/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5373 - accuracy: 0.3462
# Epoch 82/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5156 - accuracy: 0.2308
# Epoch 83/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5565 - accuracy: 0.3462
# Epoch 84/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5250 - accuracy: 0.2885
# Epoch 85/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5090 - accuracy: 0.3269
# Epoch 86/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5132 - accuracy: 0.3462
# Epoch 87/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5202 - accuracy: 0.3462
# Epoch 88/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5085 - accuracy: 0.3654
# Epoch 89/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5216 - accuracy: 0.3077
# Epoch 90/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5158 - accuracy: 0.3462
# Epoch 91/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5267 - accuracy: 0.2692
# Epoch 92/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5201 - accuracy: 0.2885
# Epoch 93/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5304 - accuracy: 0.3462
# Epoch 94/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5094 - accuracy: 0.3462
# Epoch 95/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5211 - accuracy: 0.2500
# Epoch 96/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5236 - accuracy: 0.3462
# Epoch 97/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5233 - accuracy: 0.3462
# Epoch 98/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5562 - accuracy: 0.3269
# Epoch 99/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5240 - accuracy: 0.3462
# Epoch 100/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5141 - accuracy: 0.3077
# Epoch 101/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5198 - accuracy: 0.2308
# Epoch 102/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5180 - accuracy: 0.3462
# Epoch 103/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5184 - accuracy: 0.3077
# Epoch 104/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5051 - accuracy: 0.3462
# Epoch 105/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5243 - accuracy: 0.3462
# Epoch 106/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5224 - accuracy: 0.2692
# Epoch 107/200
# 11/11 [==============================] - 0s 5ms/step - loss: 1.5158 - accuracy: 0.3462
# Epoch 108/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5095 - accuracy: 0.3462
# Epoch 109/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5191 - accuracy: 0.2500
# Epoch 110/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5337 - accuracy: 0.3462
# Epoch 111/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5525 - accuracy: 0.3077
# Epoch 112/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5303 - accuracy: 0.3462
# Epoch 113/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5382 - accuracy: 0.2500
# Epoch 114/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5239 - accuracy: 0.3077
# Epoch 115/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5093 - accuracy: 0.3077
# Epoch 116/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5404 - accuracy: 0.1731
# Epoch 117/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5286 - accuracy: 0.3462
# Epoch 118/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5233 - accuracy: 0.3077
# Epoch 119/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5364 - accuracy: 0.3462
# Epoch 120/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5244 - accuracy: 0.3462
# Epoch 121/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5235 - accuracy: 0.3462
# Epoch 122/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5114 - accuracy: 0.2308
# Epoch 123/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5202 - accuracy: 0.3269
# Epoch 124/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5353 - accuracy: 0.3462
# Epoch 125/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5316 - accuracy: 0.2500
# Epoch 126/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5194 - accuracy: 0.3269
# Epoch 127/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5511 - accuracy: 0.3269
# Epoch 128/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5186 - accuracy: 0.2308
# Epoch 129/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5154 - accuracy: 0.3462
# Epoch 130/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5210 - accuracy: 0.3462
# Epoch 131/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5135 - accuracy: 0.3462
# Epoch 132/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5239 - accuracy: 0.2692
# Epoch 133/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5269 - accuracy: 0.3077
# Epoch 134/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5567 - accuracy: 0.3462
# Epoch 135/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5051 - accuracy: 0.3462
# Epoch 136/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5382 - accuracy: 0.3077
# Epoch 137/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5229 - accuracy: 0.3462
# Epoch 138/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5081 - accuracy: 0.3462
# Epoch 139/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5393 - accuracy: 0.2115
# Epoch 140/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5188 - accuracy: 0.2885
# Epoch 141/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5207 - accuracy: 0.2885
# Epoch 142/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5308 - accuracy: 0.3654
# Epoch 143/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5253 - accuracy: 0.3462
# Epoch 144/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5298 - accuracy: 0.3462
# Epoch 145/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5150 - accuracy: 0.3077
# Epoch 146/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5253 - accuracy: 0.3077
# Epoch 147/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5200 - accuracy: 0.3462
# Epoch 148/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5160 - accuracy: 0.3462
# Epoch 149/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5162 - accuracy: 0.2692
# Epoch 150/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5091 - accuracy: 0.3462
# Epoch 151/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5066 - accuracy: 0.3462
# Epoch 152/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5256 - accuracy: 0.2885
# Epoch 153/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5344 - accuracy: 0.3462
# Epoch 154/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5436 - accuracy: 0.2500
# Epoch 155/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5453 - accuracy: 0.1538
# Epoch 156/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5147 - accuracy: 0.2885
# Epoch 157/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5141 - accuracy: 0.3462
# Epoch 158/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5133 - accuracy: 0.3462
# Epoch 159/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5193 - accuracy: 0.3462
# Epoch 160/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5465 - accuracy: 0.2692
# Epoch 161/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5222 - accuracy: 0.3077
# Epoch 162/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5443 - accuracy: 0.3462
# Epoch 163/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5269 - accuracy: 0.3462
# Epoch 164/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5352 - accuracy: 0.2308
# Epoch 165/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5206 - accuracy: 0.3462
# Epoch 166/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5108 - accuracy: 0.3462
# Epoch 167/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5086 - accuracy: 0.2692
# Epoch 168/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5150 - accuracy: 0.3462
# Epoch 169/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5190 - accuracy: 0.3462
# Epoch 170/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5130 - accuracy: 0.3462
# Epoch 171/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5161 - accuracy: 0.2885
# Epoch 172/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5099 - accuracy: 0.3462
# Epoch 173/200
# 11/11 [==============================] - 0s 4ms/step - loss: 1.5205 - accuracy: 0.3462
# Epoch 174/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5244 - accuracy: 0.2308
# Epoch 175/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5107 - accuracy: 0.3462
# Epoch 176/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5476 - accuracy: 0.3462
# Epoch 177/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5322 - accuracy: 0.3462
# Epoch 178/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5232 - accuracy: 0.2885
# Epoch 179/200
# 11/11 [==============================] - 0s 1ms/step - loss: 1.5265 - accuracy: 0.2500
# Epoch 180/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5365 - accuracy: 0.3462
# Epoch 181/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5180 - accuracy: 0.3462
# Epoch 182/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5150 - accuracy: 0.2885
# Epoch 183/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5179 - accuracy: 0.3077
# Epoch 184/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5199 - accuracy: 0.3462
# Epoch 185/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5333 - accuracy: 0.2308
# Epoch 186/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5117 - accuracy: 0.3462
# Epoch 187/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5180 - accuracy: 0.2692
# Epoch 188/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5246 - accuracy: 0.3462
# Epoch 189/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5192 - accuracy: 0.3462
# Epoch 190/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5155 - accuracy: 0.2885
# Epoch 191/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5237 - accuracy: 0.3462
# Epoch 192/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5176 - accuracy: 0.3462
# Epoch 193/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5093 - accuracy: 0.3462
# Epoch 194/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5117 - accuracy: 0.3462
# Epoch 195/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5295 - accuracy: 0.3462
# Epoch 196/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5157 - accuracy: 0.2308
# Epoch 197/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5283 - accuracy: 0.3077
# Epoch 198/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5219 - accuracy: 0.2500
# Epoch 199/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5222 - accuracy: 0.3462
# Epoch 200/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5389 - accuracy: 0.3462
# Done
